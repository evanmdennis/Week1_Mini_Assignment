# %%
#Starting Out with some basic math

# %%
4+6
# Out:
# 10

# %%
x = 47

# %%
x + 8
# Out:
# 55

# %%
#Just adding some text

# %%
print("And now I am printing some text")
# Out:
# And now I am printing some text

# %%
(4+5)/2
# Out:
# 4.5

# %%
#^^ I guess that is a float

# %%
(4+5)//2
# Out:
# 4

# %%
(4+5)%2
# Out:
# 1

# %%
4**2
# Out:
# 16

# %%
print("Let's use some variables")
# Out:
# Let's use some variables

# %%
y = "Sounds good!"

# %%
print(y)
# Out:
# Sounds good!

# %%
4+3
# Out:
# 7

# %%
_/3
# Out:
# 2.3333333333333335

# %%
round(_,3)
# Out:
# 2.333

# %%
'Let\'s use the back slash to escape single quotes'
# Out:
# "Let's use the back slash to escape single quotes"

# %%
print("""Let's use 
multiple 
lines
# !!!!""")
# Out:
# Let's use
# multiple
# lines
# !!!!

# %%
print("""Or we \
could prevent that""")
# Out:
# Or we could prevent that

# %%
"ba"+'na'
# Out:
# 'bana'

# %%
'ba'+2*'na'
# Out:
# 'banana'

# %%
 'I '+3*'love' + ' bananas!'
# Out:
# 'I lovelovelove bananas!'

# %%
'these three parts ''will join auto' 'matically'
# Out:
# 'these three parts will join automatically'

# %%
word = 'banana' #Let's use index feature

# %%
word[3]
# Out:
# 'a'

# %%
word[-3]
# Out:
# 'a'

# %%
word[2:6]
# Out:
# 'nana'

# %%
word[2:] #I don't need that second number
# Out:
# 'nana'

# %%
print('I love '+ word)
# Out:
# I love banana

# %%
print('I love '+ word[2:])
# Out:
# I love nana

# %%
len(word)
# Out:
# 6

# %%
my_list = [4,8,15,16,23,42] #Anyone a fan of Lost?

# %%
my_list[2]
# Out:
# 15

# %%
z = my_list[2]

# %%
z/3
# Out:
# 5.0

# %%
my_list[2]=21

# %%
my_list
# Out:
# [4, 8, 21, 16, 23, 42]

# %%
my_list.append(54)

# %%
my_list
# Out:
# [4, 8, 21, 16, 23, 42, 54]

# %%
my_list[2:4]=[1,2,3]

# %%
my_list
# Out:
# [4, 8, 1, 2, 3, 23, 42, 54]

# %%
a,b= ['b','a','n'],['a','n','a']

# %%
delicious = [a,b] #Lists of lists

# %%
delicious
# Out:
# [['b', 'a', 'n'], ['a', 'n', 'a']]

# %%
b
# Out:
# ['a', 'n', 'a']

# %%
c=[5,78,105,235,567]
